# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Train Data

# %%
train_df = pd.read_csv('../dataset/train.csv')
display(train_df.head(8))

# Histogram of the target variable
plt.hist(train_df['Credit_Score'], bins=5)
plt.xlabel('Credit_Score')
plt.ylabel('Frequency')
plt.title('Histogram of Credit_Score [Train]')
plt.show()
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_13708\1692306374.py:1: DtypeWarning: Columns (26) have mixed types. Specify dtype option on import or set low_memory=False.
#   train_df = pd.read_csv('../dataset/train.csv')
#        ID Customer_ID     Month           Name   Age          SSN Occupation  \
# 0  0x1602   CUS_0xd40   January  Aaron Maashoh    23  821-00-0265  Scientist
# 1  0x1603   CUS_0xd40  February  Aaron Maashoh    23  821-00-0265  Scientist
# 2  0x1604   CUS_0xd40     March  Aaron Maashoh  -500  821-00-0265  Scientist
# 3  0x1605   CUS_0xd40     April  Aaron Maashoh    23  821-00-0265  Scientist
# 4  0x1606   CUS_0xd40       May  Aaron Maashoh    23  821-00-0265  Scientist
# 5  0x1607   CUS_0xd40      June  Aaron Maashoh    23  821-00-0265  Scientist
# 6  0x1608   CUS_0xd40      July  Aaron Maashoh    23  821-00-0265  Scientist
# 7  0x1609   CUS_0xd40    August            NaN    23    #F%$D@*&8  Scientist
#
# ...

# %%
# Info
display(train_df.info())
display(train_df.describe())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 28 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   ID                        100000 non-null  object
#  1   Customer_ID               100000 non-null  object
#  2   Month                     100000 non-null  object
#  3   Name                      90015 non-null   object
#  4   Age                       100000 non-null  object
#  5   SSN                       100000 non-null  object
#  6   Occupation                100000 non-null  object
#  7   Annual_Income             100000 non-null  object
#  8   Monthly_Inhand_Salary     84998 non-null   float64
#  9   Num_Bank_Accounts         100000 non-null  int64
#  10  Num_Credit_Card           100000 non-null  int64
#  11  Interest_Rate             100000 non-null  int64
#  12  Num_of_Loan               100000 non-null  object
# ...

# %%
# No of Unique values
display(train_df.nunique())
# Out:
# ID                          100000
# Customer_ID                  12500
# Month                            8
# Name                         10139
# Age                           1788
# SSN                          12501
# Occupation                      16
# Annual_Income                18940
# Monthly_Inhand_Salary        13235
# Num_Bank_Accounts              943
# Num_Credit_Card               1179
# Interest_Rate                 1750
# Num_of_Loan                    434
# Type_of_Loan                  6260
# Delay_from_due_date             73
# Num_of_Delayed_Payment         749
# Changed_Credit_Limit          4384
# Num_Credit_Inquiries          1223
# Credit_Mix                       4
# Outstanding_Debt             13178
# Credit_Utilization_Ratio    100000
# Credit_History_Age             404
# Payment_of_Min_Amount            3
# Total_EMI_per_month          14950
# Amount_invested_monthly      91049
# Payment_Behaviour                7
# Monthly_Balance              98792
# ...

# %% [markdown]
# ##### Visualizing the data

# %%
def visualize_column(data, col):
    """
    Visualize the given column in the DataFrame.

    Parameters:
    data (pd.DataFrame): The DataFrame containing the data.
    col (str): The name of the column to visualize.
    """
    if col == 'ID':
        return
    
    plt.figure(figsize=(8, 6))
    if data[col].dtype == 'object':
        sns.countplot(data=data, x=col)
        plt.title(f'Count Plot for {col}')
        plt.xticks(rotation=45)
    else:
        sns.histplot(data=data, x=col, kde=True)
        plt.title(f'Histogram for {col}')
    plt.show()


def visualize_categories(data, col):
    """
    Visualize the unique categories in the given column of the DataFrame.

    Parameters:
    data (pd.DataFrame): The DataFrame containing the data.
    col (str): The name of the column to visualize.
    """
    if col == 'ID':
        return
    x=np.array(data[col].unique())
    print(x)
    
    # # Get unique categories
    # unique_categories = data[col].unique()
    
    # plt.figure(figsize=(8, 6))
    # sns.countplot(data=data, x=col, order=unique_categories)
    # plt.title(f'Unique Categories for {col}')
    # plt.xticks(rotation=45)
    # plt.show()

# %%
columns=train_df.columns
print(columns)
# Out:
# Index(['ID', 'Customer_ID', 'Month', 'Name', 'Age', 'SSN', 'Occupation',
#        'Annual_Income', 'Monthly_Inhand_Salary', 'Num_Bank_Accounts',
#        'Num_Credit_Card', 'Interest_Rate', 'Num_of_Loan', 'Type_of_Loan',
#        'Delay_from_due_date', 'Num_of_Delayed_Payment', 'Changed_Credit_Limit',
#        'Num_Credit_Inquiries', 'Credit_Mix', 'Outstanding_Debt',
#        'Credit_Utilization_Ratio', 'Credit_History_Age',
#        'Payment_of_Min_Amount', 'Total_EMI_per_month',
#        'Amount_invested_monthly', 'Payment_Behaviour', 'Monthly_Balance',
#        'Credit_Score'],
#       dtype='object')

# %%
# ID
# Customer ID

# Month
visualize_column(train_df, 'Month')

# %%
# 'Name'
# 'Age'
visualize_categories(train_df, 'Age')
# visualize_column(train_df, 'Age')
# 'SSN',
# Out:
# ['23' '-500' '28_' ... '4808_' '2263' '1342']

# %%
# Occupation
visualize_column(train_df, 'Occupation')

# %%
# Annual_Income
visualize_column(train_df, 'Annual_Income')

# %%
# Monthly_Inhand_Salary
visualize_column(train_df, 'Monthly_Inhand_Salary')

# %%
# Num_Bank_Accounts
visualize_column(train_df, 'Num_Bank_Accounts')

# %%
# Num_Credit_Card
visualize_column(train_df, 'Num_Credit_Card')

# %%
# Interest_Rate
visualize_column(train_df, 'Interest_Rate')

# %%
# Num_of_Loan
visualize_column(train_df, 'Num_of_Loan')

# %%
# Type_of_Loan
visualize_column(train_df, 'Type_of_Loan')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[20], line 2
#       1 # Type_of_Loan
# ----> 2 visualize_column(train_df, 'Type_of_Loan')
#
# Cell In[7], line 20, in visualize_column(data, col)
#      18     sns.histplot(data=data, x=col, kde=True)
#      19     plt.title(f'Histogram for {col}')
# ---> 20 plt.show()
#
# File c:\Users\Dell\AppData\Local\Programs\Python\Python310\lib\site-packages\matplotlib\pyplot.py:421, in show(*args, **kwargs)
#     377 """
#     378 Display all open figures.
#     379
#    (...)
#     418 explicitly there.
#     419 """
#     420 _warn_if_gui_out_of_main_thread()
# --> 421 return _get_backend_mod().show(*args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\matplotlib_inline\backend_inline.py:90, in show(close, block)
#      88 try:
#      89     for figure_manager in Gcf.get_all_fig_managers():
# ...

# %%
# Delay_from_due_date
visualize_column(train_df, 'Delay_from_due_date')

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Calculate number of rows needed
num_cols = 3
num_rows = (len(train_df.columns) + num_cols - 1) // num_cols

# Create subplots
fig, axes = plt.subplots(num_rows, num_cols, figsize=(15, num_rows*5))

# Flatten axes array
axes = axes.flatten()

# Iterate over each column
for i, col in enumerate(train_df.columns):
    print(f'Processing column {col}')
    if col == 'ID':
        continue
    # Check if column is numeric or categorical
    if train_df[col].dtype == 'object':
        # For categorical data, create a count plot
        # Show the unique categories
    
        sns.countplot(data=train_df, x=col, ax=axes[i])
        axes[i].set_title(f'Count Plot for {col}')
        axes[i].set_xticklabels(axes[i].get_xticklabels(), rotation=45)
    else:
        # For numeric data, create a histogram
        sns.histplot(data=train_df, x=col, kde=True, ax=axes[i])
        axes[i].set_title(f'Histogram for {col}')

# Hide unused subplots
for j in range(i+1, num_rows*num_cols):
    axes[j].axis('off')

# Adjust layout
plt.tight_layout()
plt.show()
# Out:
# Processing column ID
# Processing column Customer_ID
# Processing column Month
# Processing column Name
# Processing column Age
# Processing column SSN
# Processing column Occupation
# Processing column Annual_Income
# Processing column Monthly_Inhand_Salary
# Processing column Num_Bank_Accounts
# Processing column Num_Credit_Card
# Processing column Interest_Rate
# Processing column Num_of_Loan
# Processing column Type_of_Loan
# Processing column Delay_from_due_date
# Processing column Num_of_Delayed_Payment
# Processing column Changed_Credit_Limit
# Processing column Num_Credit_Inquiries
# Processing column Credit_Mix
# Processing column Outstanding_Debt
# Processing column Credit_Utilization_Ratio
# Processing column Credit_History_Age
# Processing column Payment_of_Min_Amount
# Processing column Total_EMI_per_month
# Processing column Amount_invested_monthly

# %% [markdown]
# ### Test Data

# %%
test_df = pd.read_csv('../dataset/test.csv')
display(test_df.head())

# Histogram of the target variable
plt.hist(train_df['Credit_Score'], bins=5)
plt.xlabel('Credit_Score')
plt.ylabel('Frequency')
plt.title('Histogram of Credit_Score [Test]')
plt.show()
# Out:
#        ID Customer_ID      Month             Name  Age          SSN  \
# 0  0x160a   CUS_0xd40  September    Aaron Maashoh   23  821-00-0265
# 1  0x160b   CUS_0xd40    October    Aaron Maashoh   24  821-00-0265
# 2  0x160c   CUS_0xd40   November    Aaron Maashoh   24  821-00-0265
# 3  0x160d   CUS_0xd40   December    Aaron Maashoh  24_  821-00-0265
# 4  0x1616  CUS_0x21b1  September  Rick Rothackerj   28  004-07-5839
#
#   Occupation Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  ...  \
# 0  Scientist      19114.12            1824.843333                  3  ...
# 1  Scientist      19114.12            1824.843333                  3  ...
# 2  Scientist      19114.12            1824.843333                  3  ...
# 3  Scientist      19114.12                    NaN                  3  ...
# 4    _______      34847.84            3037.986667                  2  ...
#
#    Num_Credit_Inquiries  Credit_Mix Outstanding_Debt Credit_Utilization_Ratio  \
# ...

# %%
train_df.info()

# %%
from pprint import pprint

# Assuming your DataFrame is named 'train_df'
features = train_df.columns.tolist()

# Print column index and name
for idx, feature in enumerate(features):
    print(f"{idx}: {feature}")
# Out:
# 0: ID
# 1: Customer_ID
# 2: Month
# 3: Name
# 4: Age
# 5: SSN
# 6: Occupation
# 7: Annual_Income
# 8: Monthly_Inhand_Salary
# 9: Num_Bank_Accounts
# 10: Num_Credit_Card
# 11: Interest_Rate
# 12: Num_of_Loan
# 13: Type_of_Loan
# 14: Delay_from_due_date
# 15: Num_of_Delayed_Payment
# 16: Changed_Credit_Limit
# 17: Num_Credit_Inquiries
# 18: Credit_Mix
# 19: Outstanding_Debt
# 20: Credit_Utilization_Ratio
# 21: Credit_History_Age
# 22: Payment_of_Min_Amount
# 23: Total_EMI_per_month
# 24: Amount_invested_monthly
# 25: Payment_Behaviour
# 26: Monthly_Balance
# 27: Credit_Score

# %%
from pprint import pprint

# Assuming your DataFrame is named 'train_df'
features = test_df.columns.tolist()

# Print column index and name
for idx, feature in enumerate(features):
    print(f"{idx}: {feature}")
# Out:
# 0: ID
# 1: Customer_ID
# 2: Month
# 3: Name
# 4: Age
# 5: SSN
# 6: Occupation
# 7: Annual_Income
# 8: Monthly_Inhand_Salary
# 9: Num_Bank_Accounts
# 10: Num_Credit_Card
# 11: Interest_Rate
# 12: Num_of_Loan
# 13: Type_of_Loan
# 14: Delay_from_due_date
# 15: Num_of_Delayed_Payment
# 16: Changed_Credit_Limit
# 17: Num_Credit_Inquiries
# 18: Credit_Mix
# 19: Outstanding_Debt
# 20: Credit_Utilization_Ratio
# 21: Credit_History_Age
# 22: Payment_of_Min_Amount
# 23: Total_EMI_per_month
# 24: Amount_invested_monthly
# 25: Payment_Behaviour
# 26: Monthly_Balance

# %%
# get customer id column
customer_id = train_df['Customer_ID']

# make check that every 8 rows have the same customer id
for i in range(0, len(customer_id), 8):
    assert len(set(customer_id[i:i+8])) == 1, f"Customer ID {customer_id[i]} has different values"
    # precenage of completion
    print(f"{i/len(customer_id)*100:.2f}%", end='\r')
print("All customers have 8 rows")
    
customer_id = test_df['Customer_ID']

# make check that every 8 rows have the same customer id
for i in range(0, len(customer_id), 8):
    assert len(set(customer_id[i:i+8])) == 1, f"Customer ID {customer_id[i]} has different values"
    # precenage of completion
    print(f"{i/len(customer_id)*100:.2f}%", end='\r')
print("All customers have 8 rows")
# Out:
# All customers have 8 rows
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-8-16f1432846fe> in <module>
#      13 # make check that every 8 rows have the same customer id
#      14 for i in range(0, len(customer_id), 8):
# ---> 15     assert len(set(customer_id[i:i+8])) == 1, f"Customer ID {customer_id[i]} has different values"
#      16     # precenage of completion
#      17     print(f"{i/len(customer_id)*100:.2f}%", end='\r')
#
# AssertionError: Customer ID CUS_0xd40 has different values
